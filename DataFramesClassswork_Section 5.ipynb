# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rishabh\\Desktop\\pythonAtoZ'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rishabh\\Desktop\\pythonAtoZ'

# %%
stats=pd.read_csv('sample_data\\flights.csv')

# %%
flightStats= pd.read_csv('sample_data\\')

# %%
stats
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
len(stats)
# Out:
# 1460

# %%
stats.columns
# Out:
# Index(['permalink', 'company', 'numEmps', 'category', 'city', 'state',
#        'fundedDate', 'raisedAmt', 'raisedCurrency', 'round'],
#       dtype='object')

# %%
stats.head(5) #return top x rows
# Out:
#      permalink      company  numEmps category        city state fundedDate  \
# 0     lifelock     LifeLock      NaN      web       Tempe    AZ   1-May-07
# 1     lifelock     LifeLock      NaN      web       Tempe    AZ   1-Oct-06
# 2     lifelock     LifeLock      NaN      web       Tempe    AZ   1-Jan-08
# 3  mycityfaces  MyCityFaces      7.0      web  Scottsdale    AZ   1-Jan-08
# 4     flypaper     Flypaper      NaN      web     Phoenix    AZ   1-Feb-08
#
#    raisedAmt raisedCurrency round
# 0    6850000            USD     b
# 1    6000000            USD     a
# 2   25000000            USD     c
# 3      50000            USD  seed
# 4    3000000            USD     a

# %%
#x bottom rows
stats.tail(6)
# Out:
#           permalink        company  numEmps  category      city state  \
# 1454           cozi           Cozi     26.0  software   Seattle    WA
# 1455        trusera        Trusera     15.0       web   Seattle    WA
# 1456     alerts-com     Alerts.com      NaN       web  Bellevue    WA
# 1457          myrio          Myrio     75.0  software   Bothell    WA
# 1458  grid-networks  Grid Networks      NaN       web   Seattle    WA
# 1459  grid-networks  Grid Networks      NaN       web   Seattle    WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 1454   1-Jun-08    8000000            USD             c
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
# permalink         1460 non-null object
# company           1460 non-null object
# numEmps           567 non-null float64
# category          1436 non-null object
# city              1442 non-null object
# state             1460 non-null object
# fundedDate        1460 non-null object
# raisedAmt         1460 non-null int64
# raisedCurrency    1460 non-null object
# round             1460 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 114.1+ KB

# %%
stats.describe()
# Out:
#             numEmps     raisedAmt
# count    567.000000  1.460000e+03
# mean      95.721340  1.013149e+07
# std      867.524287  1.866146e+07
# min        0.000000  6.000000e+03
# 25%        8.000000  2.000000e+06
# 50%       20.000000  5.500000e+06
# 75%       50.000000  1.102500e+07
# max    20000.000000  3.000000e+08

# %%
stats.describe().transpose()
# Out:
#             count          mean           std     min        25%        50%  \
# numEmps     567.0  9.572134e+01  8.675243e+02     0.0        8.0       20.0
# raisedAmt  1460.0  1.013149e+07  1.866146e+07  6000.0  2000000.0  5500000.0
#
#                   75%          max
# numEmps          50.0      20000.0
# raisedAmt  11025000.0  300000000.0

# %%
stats.head()
# Out:
#      permalink      company  numEmps category        city state fundedDate  \
# 0     lifelock     LifeLock      NaN      web       Tempe    AZ   1-May-07
# 1     lifelock     LifeLock      NaN      web       Tempe    AZ   1-Oct-06
# 2     lifelock     LifeLock      NaN      web       Tempe    AZ   1-Jan-08
# 3  mycityfaces  MyCityFaces      7.0      web  Scottsdale    AZ   1-Jan-08
# 4     flypaper     Flypaper      NaN      web     Phoenix    AZ   1-Feb-08
#
#    raisedAmt raisedCurrency round
# 0    6850000            USD     b
# 1    6000000            USD     a
# 2   25000000            USD     c
# 3      50000            USD  seed
# 4    3000000            USD     a

# %%
stats.columns
# Out:
# Index(['permalink', 'company', 'numEmps', 'category', 'city', 'state',
#        'fundedDate', 'raisedAmt', 'raisedCurrency', 'round'],
#       dtype='object')

# %%
#Slice rows
stats[4:10]
# Out:
#         permalink         company  numEmps  category           city state  \
# 4        flypaper        Flypaper      NaN       web        Phoenix    AZ
# 5    infusionsoft    Infusionsoft    105.0  software        Gilbert    AZ
# 6           gauto           gAuto      4.0       web     Scottsdale    AZ
# 7  chosenlist-com  ChosenList.com      5.0       web     Scottsdale    AZ
# 8  chosenlist-com  ChosenList.com      5.0       web     Scottsdale    AZ
# 9            digg            Digg     60.0       web  San Francisco    CA
#
#   fundedDate  raisedAmt raisedCurrency  round
# 4   1-Feb-08    3000000            USD      a
# 5   1-Oct-07    9000000            USD      a
# 6   1-Jan-08     250000            USD   seed
# 7   1-Oct-06     140000            USD   seed
# 8  25-Jan-08     233750            USD  angel
# 9   1-Dec-06    8500000            USD      b

# %%
stats[:10] #stats.head(10)
# Out:
#         permalink         company  numEmps  category           city state  \
# 0        lifelock        LifeLock      NaN       web          Tempe    AZ
# 1        lifelock        LifeLock      NaN       web          Tempe    AZ
# 2        lifelock        LifeLock      NaN       web          Tempe    AZ
# 3     mycityfaces     MyCityFaces      7.0       web     Scottsdale    AZ
# 4        flypaper        Flypaper      NaN       web        Phoenix    AZ
# 5    infusionsoft    Infusionsoft    105.0  software        Gilbert    AZ
# 6           gauto           gAuto      4.0       web     Scottsdale    AZ
# 7  chosenlist-com  ChosenList.com      5.0       web     Scottsdale    AZ
# 8  chosenlist-com  ChosenList.com      5.0       web     Scottsdale    AZ
# 9            digg            Digg     60.0       web  San Francisco    CA
#
#   fundedDate  raisedAmt raisedCurrency  round
# 0   1-May-07    6850000            USD      b
# 1   1-Oct-06    6000000            USD      a
# ...

# %%
stats[::-1]
# Out:
#                permalink              company  numEmps   category  \
# 1459       grid-networks        Grid Networks      NaN        web
# 1458       grid-networks        Grid Networks      NaN        web
# 1457               myrio                Myrio     75.0   software
# 1456          alerts-com           Alerts.com      NaN        web
# 1455             trusera              Trusera     15.0        web
# 1454                cozi                 Cozi     26.0   software
# 1453                cozi                 Cozi     26.0   software
# 1452           m-metrics            M:Metrics      NaN        web
# 1451             infinia              Infinia      NaN  cleantech
# 1450             infinia              Infinia      NaN  cleantech
# 1449            estately             Estately      NaN        web
# 1448         teachstreet          TeachStreet      8.0        web
# 1447               mpire                mpire      NaN        web
# ...

# %%
#get every 20th row
stats[0:1460:20]
# Out:
#                                    permalink                   company  \
# 0                                   lifelock                  LifeLock
# 20                                 omnidrive                 Omnidrive
# 40                                technorati                Technorati
# 60                                   mercora                   Mercora
# 80                                 revision3                 Revision3
# 100                                   meevee                    MeeVee
# 120                                   swivel                    Swivel
# 140                                  pandora                   Pandora
# 160                                 terabitz                  Terabitz
# 180                                   zvents                    Zvents
# 200                             powerreviews               PowerReview
# 220                                    curse                     Curse
# ...

# %%
#Columns
stats.columns
# Out:
# Index(['permalink', 'company', 'numEmps', 'category', 'city', 'state',
#        'fundedDate', 'raisedAmt', 'raisedCurrency', 'round'],
#       dtype='object')

# %%
stats['company'].head()
# Out:
# 0       LifeLock
# 1       LifeLock
# 2       LifeLock
# 3    MyCityFaces
# 4       Flypaper
# Name: company, dtype: object

# %%
stats[['company','city']].head()
# Out:
#        company        city
# 0     LifeLock       Tempe
# 1     LifeLock       Tempe
# 2     LifeLock       Tempe
# 3  MyCityFaces  Scottsdale
# 4     Flypaper     Phoenix

# %%
#squeezing dataset- combining the two- 2 subset
stats[4:10][['company','city']]
# Out:
#           company           city
# 4        Flypaper        Phoenix
# 5    Infusionsoft        Gilbert
# 6           gAuto     Scottsdale
# 7  ChosenList.com     Scottsdale
# 8  ChosenList.com     Scottsdale
# 9            Digg  San Francisco

# %%
#Quick access
stats.company
# Out:
# 0                  LifeLock
# 1                  LifeLock
# 2                  LifeLock
# 3               MyCityFaces
# 4                  Flypaper
# 5              Infusionsoft
# 6                     gAuto
# 7            ChosenList.com
# 8            ChosenList.com
# 9                      Digg
# 10                     Digg
# 11                 Facebook
# 12                 Facebook
# 13                 Facebook
# 14                 Facebook
# 15                 Facebook
# 16                 Facebook
# 17                 Facebook
# 18              Photobucket
# 19              Photobucket
# 20                Omnidrive
# 21                     Geni
# 22                     Geni
# 23                  Twitter
# 24                  Twitter
# 25              StumbleUpon
# 26                   Gizmoz
# 27                   Gizmoz
# 28                   Scribd
# 29                   Scribd
#                ...
# 1430               Fyreball
# 1431         Delve Networks
# ...

# %%
#Mathematical operations
stats2=stats.raisedAmt*2

# %%
stats2.head()
# Out:
# 0    13700000
# 1    12000000
# 2    50000000
# 3      100000
# 4     6000000
# Name: raisedAmt, dtype: int64

# %%
stats['addedColumn']=stats2

# %%
stats=stats.drop('addedColumn',axis=1)

# %%
stats.head()
# Out:
#      permalink      company  numEmps category        city state fundedDate  \
# 0     lifelock     LifeLock      NaN      web       Tempe    AZ   1-May-07
# 1     lifelock     LifeLock      NaN      web       Tempe    AZ   1-Oct-06
# 2     lifelock     LifeLock      NaN      web       Tempe    AZ   1-Jan-08
# 3  mycityfaces  MyCityFaces      7.0      web  Scottsdale    AZ   1-Jan-08
# 4     flypaper     Flypaper      NaN      web     Phoenix    AZ   1-Feb-08
#
#    raisedAmt raisedCurrency round
# 0    6850000            USD     b
# 1    6000000            USD     a
# 2   25000000            USD     c
# 3      50000            USD  seed
# 4    3000000            USD     a

# %%
##Filtering data frame
##Filtering of rows
filter=stats.raisedAmt<100000

# %%
stats[filter].head()
# Out:
#        permalink      company  numEmps category           city state  \
# 3    mycityfaces  MyCityFaces      7.0      web     Scottsdale    AZ
# 28        scribd       Scribd     14.0      web  San Francisco    CA
# 29        scribd       Scribd     14.0      web  San Francisco    CA
# 109       zooomr       Zooomr      NaN      web  San Francisco    CA
# 242       buxfer       Buxfer      2.0      web  Mountain View    CA
#
#     fundedDate  raisedAmt raisedCurrency  round
# 3     1-Jan-08      50000            USD   seed
# 28    1-Jun-06      12000            USD   seed
# 29    1-Jan-07      40000            USD  angel
# 109   1-Feb-06      50000            USD  angel
# 242   1-Jan-07      15000            USD   seed

# %%
stats[filter & (stats.numEmps>10) & (stats.state=='CA')]   ## brackets are required. 'and' operator cannot be used, as it doesnt understand lists.
# Out:
#    permalink company  numEmps category           city state fundedDate  \
# 28    scribd  Scribd     14.0      web  San Francisco    CA   1-Jun-06
# 29    scribd  Scribd     14.0      web  San Francisco    CA   1-Jan-07
#
#     raisedAmt raisedCurrency  round
# 28      12000            USD   seed
# 29      40000            USD  angel

# %%
stats.state.unique()
# Out:
# array(['AZ', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'IA', 'ID', 'IL', 'IN',
#        'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'NC', 'ND', 'NE', 'NJ',
#        'NM', 'NY', 'OH', 'OR', 'PA', 'RI', 'TN', 'TX', 'UT', 'VA', 'WA'],
#       dtype=object)

# %%
sub200=stats[::200]
sub200
# Out:
#          permalink              company  numEmps  category  \
# 0         lifelock             LifeLock      NaN       web
# 200   powerreviews          PowerReview      NaN       web
# 400        realius              Realius      3.0       web
# 600       rocketon             RocketOn      NaN       web
# 800        skyfire              Skyfire      NaN  software
# 1000     carbonite            Carbonite     68.0       web
# 1200       answers  Answers Corporation      NaN       web
# 1400          ripl                 Ripl      NaN       web
#
#                      city state fundedDate  raisedAmt raisedCurrency  \
# 0                   Tempe    AZ   1-May-07    6850000            USD
# 200              Millbrae    CA   1-Dec-05    6250000            USD
# 400              Berkeley    CA   1-May-07     500000            USD
# 600   South San Francisco    CA   1-Feb-08    5800000            USD
# 800         Mountain View    CA   1-Jun-07    4800000            USD
# ...

# %%
## at and iat. at --> labels.. iat--> looks for indexes or sequences
sub200.at[400,'city'] # iat looks for labels-->column name and row name
# Out:
# 'Berkeley'

# %%
sub200.iat[2,4] ##iat looks for sequence
# Out:
# 'Berkeley'

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=8,4

# %%
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.distplot(stats["passengers"],bins=12)

# %%
#boxplots
vis2= sns.boxplot(data=stats,x='month',y='passengers')

# %%
vis2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f9b662f60ea1> in <module>()
# ----> 1 vis2
#
# NameError: name 'vis2' is not defined

# %%
stats.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
vis3= sns.lmplot(data=stats,x='year',y='passengers',hue='month',scatter_kws={'s':100}) #linear relationship, passengers increasing with year
